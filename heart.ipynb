# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix

# %%
# importing our data set

# %%
df = pd.read_csv('/content/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
## Staring our data pre- processing

# %%
#from sklearn.preprocessing import MinMaxScaler

# %%
#scale = MinMaxScaler

# %%
#df1=scale.fit_transform(df[['age','sex','cp',	'trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']])

# %%
#df1
# Out:
# array([[-0.26843658,  0.66150409, -0.91575542, ...,  0.99543334,
#          1.20922066,  1.08985168],
#        [-0.15815703,  0.66150409, -0.91575542, ..., -2.24367514,
#         -0.73197147,  1.08985168],
#        [ 1.71659547,  0.66150409, -0.91575542, ..., -2.24367514,
#         -0.73197147,  1.08985168],
#        ...,
#        [-0.81983438,  0.66150409, -0.91575542, ..., -0.6241209 ,
#          0.23862459, -0.52212231],
#        [-0.4889957 , -1.51170646, -0.91575542, ...,  0.99543334,
#         -0.73197147, -0.52212231],
#        [-0.04787747,  0.66150409, -0.91575542, ..., -0.6241209 ,
#          0.23862459,  1.08985168]])

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.isnull()
# Out:
#         age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0     False  False  False     False  False  False    False    False  False
# 1     False  False  False     False  False  False    False    False  False
# 2     False  False  False     False  False  False    False    False  False
# 3     False  False  False     False  False  False    False    False  False
# 4     False  False  False     False  False  False    False    False  False
# ...     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 1020  False  False  False     False  False  False    False    False  False
# 1021  False  False  False     False  False  False    False    False  False
# 1022  False  False  False     False  False  False    False    False  False
# 1023  False  False  False     False  False  False    False    False  False
# 1024  False  False  False     False  False  False    False    False  False
#
#       oldpeak  slope     ca   thal  target
# ...

# %%
df.isnull().sum().reset_index().rename(columns = ({'index':'Columns' , '0':'Total NULL Values'}))
# Out:
#      Columns  0
# 0        age  0
# 1        sex  0
# 2         cp  0
# 3   trestbps  0
# 4       chol  0
# 5        fbs  0
# 6    restecg  0
# 7    thalach  0
# 8      exang  0
# 9    oldpeak  0
# 10     slope  0
# 11        ca  0
# 12      thal  0
# 13    target  0
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series[0]
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 0}, axis=1)
#               .sort_values(0, ascending=True))
#   xs = counted[0]
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# ...

# %%
 #the 0 -> unnamed column containing the sum of null values, and it is  renamed to 'Total NULL Values'.
 #it's just a way to rename the column in  DataFrame.

# %%
df['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
## 1 -> Person is having Defective Heart

## 0 -> Person is having healthy Heart

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.569138  0.827655  0.482966  134.106212  251.292585  0.164329
# 1       52.408745  0.570342  1.378327  129.245247  240.979087  0.134981
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.456914  139.130261  0.549098  1.600200  1.166333  1.158317  2.539078
# 1       0.598859  158.585551  0.134981  0.569962  1.593156  0.370722  2.119772
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_59['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_60['sex'].plot(kind='hist', bins=20, title='sex')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
## splitting data for training

# %%
x = df.drop(columns = 'target' , axis=1)
y = df['target']

# %%
x.shape
# Out:
# (1025, 13)

# %%
y.shape
# Out:
# (1025,)

# %%
X_train , X_test , Y_train , Y_test = train_test_split(x , y , test_size = 0.2 , stratify=y, random_state = 2)

# %%
print('Training Data : ' , X_train.shape , Y_train.shape)
print('Testing Data : ' , X_test.shape , Y_test.shape)
# Out:
# Training Data :  (820, 13) (820,)
# Testing Data :  (205, 13) (205,)

# %%
#test_size=0.2: This specifies that 20% of the data will be used as the test set, and
#the remaining 80% will be used as the training set.

#stratify=y: This parameter ensures that the splitting is done in a way that maintains
#the same distribution of classes in both the training and testing sets as in the original dataset.
#This is particularly useful when dealing with imbalanced datasets.

#random_state=2: This is used to set a seed for the random number generator.
#Setting a random state ensures reproducibility, meaning that if you run the code again with the same random state,
#you should get the same train/test split.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale = MinMaxScaler()

X_train_new = scale.fit_transform(X_train)
X_train_new = scale.transform(X_train)
X_test_new = scale.transform(X_test)

# %%
# converting numpy array to data frame again

# %%
X_train_new = pd.DataFrame(X_train_new , columns = X_train.columns)
X_test_new = pd.DataFrame(X_test_new , columns = X_test.columns)

# %%
X_train.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  820.000000  820.000000  820.000000  820.000000  820.000000  820.000000
# mean    54.370732    0.701220    0.948780  131.758537  247.082927    0.145122
# std      9.028330    0.458003    1.035304   17.114574   51.907055    0.352439
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.000000    0.000000    0.000000  120.000000  212.000000    0.000000
# 50%     55.500000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  820.000000  820.000000  820.000000  820.000000  820.000000  820.000000
# mean     0.531707  148.951220    0.336585    1.090610    1.385366    0.753659
# ...

# %%
X_train_new.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  820.000000  820.000000  820.000000  820.000000  820.000000  820.000000
# mean     0.528557    0.701220    0.316260    0.356213    0.276445    0.145122
# std      0.188090    0.458003    0.345101    0.161458    0.118509    0.352439
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.375000    0.000000    0.000000    0.245283    0.196347    0.000000
# 50%      0.552083    1.000000    0.333333    0.339623    0.261416    0.000000
# 75%      0.666667    1.000000    0.666667    0.433962    0.342466    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  820.000000  820.000000  820.000000  820.000000  820.000000  820.000000
# mean     0.265854    0.595047    0.336585    0.175905    0.692683    0.188415
# ...

# %%
## Now training our model

# %%
## trying all classification algorithm and will select model according to thier best accuracy

# %%
###### Applying Logistic Regression ##################

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train_new, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_new)

# %%
accuracy = accuracy_score(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# Accuracy : 53.170731707317074
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.52      0.53       106
#            1       0.51      0.55      0.53        99
#
#     accuracy                           0.53       205
#    macro avg       0.53      0.53      0.53       205
# weighted avg       0.53      0.53      0.53       205

# %%
scores = cross_val_score(model, X_train_new, Y_train, cv=5)  # 5-fold cross-validation

print("Cross-Validation Accuracy: {:.2f}% (+/- {:.2f}%)".format(scores.mean() * 100, scores.std() * 100))
# Out:
# Cross-Validation Accuracy: 85.24% (+/- 2.13%)

# %%
########## Applying decision Tree ###################

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier()

# %%
# Fit the classifier on the training data
classifier.fit(X_train_new, Y_train)

# Now you can make predictions
y_pred = classifier.predict(X_test_new)

# %%
###########################-------------- Giving 100% accuracy (Overfitting problem)----------------------->
#accuracy = accuracy_score(Y_test, y_pred)
#class_report = classification_report(Y_test, y_pred)
#print("Accuracy :", accuracy * 100)
#print("Classification Report:\n", class_report)

# %%
a=Y_train.value_counts()

# %%
print(a)
# Out:
# 1    421
# 0    399
# Name: target, dtype: int64

# %%
b = Y_test.value_counts()
print(b)
# Out:
# 1    105
# 0    100
# Name: target, dtype: int64

# %%
from sklearn.model_selection import cross_val_score


scores = cross_val_score(classifier, X_train_new, Y_train, cv=5)  # 5-fold cross-validation

print("Cross-Validation Accuracy: {:.2f}% (+/- {:.2f}%)".format(scores.mean() * 100, scores.std() * 100))
# Out:
# Cross-Validation Accuracy: 97.56% (+/- 1.34%)

# %%
## performing by giving 60% 20-20 ratio for train,test and cv

# %%
from sklearn.model_selection import train_test_split




# Split into training (60%) and temporary set (40%)
X_train_temp, X_temp, Y_train_temp, Y_temp = train_test_split(x, y, test_size=0.4, random_state=42)

# Further split the temporary set into testing (50%) and cross-validation (50%)
X_test, X_cv, Y_test, Y_cv = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# Now you have:
# - X_train_temp, Y_train_temp: 60% of the data for training
# - X_test, Y_test: 20% of the data for testing
# - X_cv, Y_cv: 20% of the data for cross-validation

# %%
# feature scaling
from sklearn.preprocessing import MinMaxScaler

scaler1 = MinMaxScaler()
X_train_scaled = scaler1.fit_transform(X_train_temp)
X_test_scaled = scaler1.transform(X_test)
X_cv_scaled = scaler1.transform(X_cv)

# %%
#model training
classifier1 = DecisionTreeClassifier()
classifier1.fit(X_train_scaled, Y_train_temp)
# Out:
# DecisionTreeClassifier()

# %%
#model prediction
Y_pred_test = classifier.predict(X_test_scaled)
Y_pred_cv = classifier.predict(X_cv_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# For Testing Set
accuracy_test = accuracy_score(Y_test, Y_pred_test)
report_test = classification_report(Y_test, Y_pred_test)

# For Cross-Validation Set
accuracy_cv = accuracy_score(Y_cv, Y_pred_cv)
report_cv = classification_report(Y_cv, Y_pred_cv)

print("Testing Set Accuracy:", accuracy_test)
print("Testing Set Classification Report:\n", report_test)

print("Cross-Validation Set Accuracy:", accuracy_cv)
print("Cross-Validation Set Classification Report:\n", report_cv)
# Out:
# Testing Set Accuracy: 0.9463414634146341
# Testing Set Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       106
#            1       0.98      0.91      0.94        99
#
#     accuracy                           0.95       205
#    macro avg       0.95      0.95      0.95       205
# weighted avg       0.95      0.95      0.95       205
#
# Cross-Validation Set Accuracy: 0.8975609756097561
# Cross-Validation Set Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90        96
#            1       0.99      0.82      0.89       109
#
#     accuracy                           0.90       205
#    macro avg       0.91      0.90      0.90       205
# weighted avg       0.91      0.90      0.90       205

# %%
##### Applying Random Forest ####

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rf_model = RandomForestClassifier()

# %%
Rf_model.fit(X_train_new, Y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = Rf_model.predict(X_test_new)

# %%
accuracy = accuracy_score(Y_test, y_pred)
class_report = classification_report(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", class_report)
# Out:
# Accuracy : 53.170731707317074
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.52      0.53       106
#            1       0.51      0.55      0.53        99
#
#     accuracy                           0.53       205
#    macro avg       0.53      0.53      0.53       205
# weighted avg       0.53      0.53      0.53       205

# %%
scores = cross_val_score(Rf_model, X_train_new, Y_train, cv=5)  # 5-fold cross-validation

print("Cross-Validation Accuracy: {:.2f}% (+/- {:.2f}%)".format(scores.mean() * 100, scores.std() * 100))
# Out:
# Cross-Validation Accuracy: 97.93% (+/- 0.73%)

# %%
###########     Applying SVM ##############

# %%
from sklearn.svm import SVC

# %%
SVM_model = SVC()

# %%
SVM_model.fit(X_train_new, Y_train)
# Out:
# SVC()

# %%
y_pred = SVM_model.predict(X_test_new)

# %%
accuracy = accuracy_score(Y_test, y_pred)
class_report = classification_report(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", class_report)
# Out:
# Accuracy : 54.63414634146342
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56       106
#            1       0.53      0.54      0.53        99
#
#     accuracy                           0.55       205
#    macro avg       0.55      0.55      0.55       205
# weighted avg       0.55      0.55      0.55       205

# %%
scores = cross_val_score(SVM_model, X_train_new, Y_train, cv=5)  # 5-fold cross-validation

print("Cross-Validation Accuracy: {:.2f}% (+/- {:.2f}%)".format(scores.mean() * 100, scores.std() * 100))
# Out:
# Cross-Validation Accuracy: 88.05% (+/- 1.83%)

# %%
########## Applying naive bayes #########

# %%
from sklearn.naive_bayes import GaussianNB

# %%
custom_priors = [0.7, 0.3]  # Let's assume class 0 has a prior probability of 0.7, and class 1 has a prior probability of 0.3

# %%
G_model = GaussianNB(priors=custom_priors)

# %%
G_model.fit(X_train_new, Y_train)
# Out:
# GaussianNB(priors=[0.7, 0.3])

# %%
y_pred = G_model.predict(X_test_new)

# %%
accuracy = accuracy_score(Y_test, y_pred)
class_report = classification_report(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", class_report)
# Out:
# Accuracy : 53.170731707317074
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.56      0.55       106
#            1       0.52      0.51      0.51        99
#
#     accuracy                           0.53       205
#    macro avg       0.53      0.53      0.53       205
# weighted avg       0.53      0.53      0.53       205

# %%
scores = cross_val_score(G_model, X_train_new, Y_train, cv=5)  # 5-fold cross-validation

print("Cross-Validation Accuracy: {:.2f}% (+/- {:.2f}%)".format(scores.mean() * 100, scores.std() * 100))
# Out:
# Cross-Validation Accuracy: 85.00% (+/- 1.31%)
